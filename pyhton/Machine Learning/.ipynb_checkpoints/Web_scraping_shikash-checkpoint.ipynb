# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
webpage = requests.get('https://engineering.careers360.com/colleges/ranking/top-engineering-colleges-in-maharashtra?sort_by=1', headers=headers).text

# %%
soup=BeautifulSoup(webpage, 'lxml')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1.0 " name="viewport"/>
#   <meta content="LGYIP8lGL_sS1s8J67ez2TByaFYHe22sDZW7IiqhXB4" name="google-site-verification"/>
#   <meta content="658BD2BEC58D06790B07B5BC052DEAC6" name="msvalidate.01"/>
#   <title>
#    Top Engineering Colleges in Maharashtra 2023 - Rank, Brochure, Compare Colleges
#   </title>
#   <meta content="Top Engineering Colleges in Maharashtra 2023 - Rank, Brochure, Compare Colleges" name="name"/>
#   <meta content="Top Engineering Colleges in Maharashtra 2023 - Careers360 brings a list of the best Engineering Colleges in Maharashtra based on extensive research parameters." name="description"/>
#   <link href="https://engineering.careers360.com/colleges/ranking/top-engineering-colleges-in-maharashtra" rel="canonical"/>
#   <meta content="colleges list" property="og:type"/>
# ...

# %%
soup.find_all('h3')[66].text
# Out:
# 'IIT Bombay - Indian Institute of Technology Bombay'

# %%
for i in soup.find_all('a'):
    print(i.text.strip())
# Out:
# Engineering and Architecture
# JEE Main 2024
# GATE 2024
# JEE Advanced 2024
# MET 2024
# KCET 2024
# AEEE 2024
# BITSAT 2024
# View All Engineering Exams
# Colleges Accepting B.Tech Applications
# Top Engineering Colleges in India
# Engineering Colleges in India
# Engineering Colleges in Tamil Nadu
# Engineering Colleges Accepting JEE Main
# Top Engineering Colleges in Hyderabad
# Top Engineering Colleges in Bangalore
# Top Engineering Colleges in Maharashtra
# JEE Main College Predictor
# JEE Main Rank Predictor
# MHT CET College Predictor
# AP EAMCET College Predictor
# TS EAMCET College Predictor
# KCET College Predictor
# JEE Advanced College Predictor
# View All College Predictors
# JEE Main Question Paper
# JEE Main Mock Test
# GATE Mock Test
# JEE Main Syllabus
# Download E-Books and Sample Papers
# Compare Colleges
# B.Tech College Applications
# BITSAT Question Paper
# Management and Business Administration
# CAT 2023
# NMAT 2023
# SNAP 2023
# IBSAT 2023
# XAT 2024
# ...

# %%
for i in soup.find_all('b'):
    print(i.text.strip())
# Out:
# 4.8/5
# 4.8/5
# 4.4/5
# 4.4/5
# 4.1/5
# 4.1/5
# 4.3/5
# 4.3/5
# 4.2/5
# 4.2/5
# 4.3/5
# 4.3/5
# 4.5/5
# 4.5/5
# 4.7/5
# 4.7/5
# 4.2/5
# 4.2/5
# 4.1/5
# 4.1/5
# 4.2/5
# 4.2/5
# 4.2/5
# 4.2/5
# 5.0/5
# 5.0/5
# 4.6/5
# 4.6/5
# 3.7/5
# 3.7/5
# 3.0/5
# 3.0/5
# 3.6/5
# 3.6/5
# 3.3/5
# 3.3/5
# 4.1/5
# 4.1/5
# 4.0/5
# 4.0/5
# 4.0/5
# 4.0/5
# 3.9/5
# 3.9/5
# 4.2/5
# 4.2/5
# 4.4/5
# 4.4/5
# 3.8/5
# 3.8/5
# 4.7/5
# 4.7/5
# 3.5/5
# 3.5/5
# 4.1/5
# 4.1/5
# 4.1/5
# 4.1/5
# 4.1/5
# 4.1/5
# 4.6/5
# 4.6/5
# 4.4/5
# 4.4/5
# 4.1/5
# 4.1/5
# 4.2/5
# 4.2/5
# 3.8/5
# 3.8/5
# 4.3/5
# 4.3/5
# 4.3/5
# 4.3/5
# 3.8/5
# 3.8/5
# 4.2/5
# 4.2/5
# 3.7/5
# 3.7/5
# 4.6/5
# 4.6/5
# 4.3/5
# 4.3/5
# 3.3/5
# 3.3/5
# 3.4/5
# 3.4/5
# 3.6/5
# 3.6/5

# %%
soup.find_all('span', class_= "star_text")
# Out:
# [<span class="star_text"> <!-- -->4.3/5</span>,
#  <span class="star_text"> <!-- -->4.6/5</span>,
#  <span class="star_text"> <!-- -->4.1/5</span>,
#  <span class="star_text"> <!-- -->4.4/5</span>,
#  <span class="star_text"> <!-- -->4.1/5</span>,
#  <span class="star_text"> <!-- -->4.4/5</span>,
#  <span class="star_text"> <!-- -->4.6/5</span>,
#  <span class="star_text"><i><svg fill="currentColor" height="1em" stroke="currentColor" stroke-width="0" viewbox="0 0 512 512" width="1em" xmlns="http://www.w3.org/2000/svg"><path d="M496 203.3H312.36L256 32l-56.36 171.3H16l150.21 105.4-58.5 171.3L256 373.84 404.29 480l-58.61-171.3z"></path></svg> </i> <b>4.8/5</b></span>,
# ...

# %%
len(soup.find_all('b'))
# Out:
# 90

# %%
soup.find_all('span', class_="review_text")
# Out:
# [<span class="review_text"><a href="https://www.careers360.com/university/amrita-vishwa-vidyapeetham-coimbatore/reviews?icn=college_sub_page&amp;ici=clg_724_college_listing_tuple">116 Reviews</a></span>,
#  <span class="review_text"><a href="https://www.careers360.com/university/manipal-academy-of-higher-education-manipal/reviews?icn=college_sub_page&amp;ici=clg_725_college_listing_tuple">24 Reviews</a></span>,
#  <span class="review_text"><a href="https://www.careers360.com/university/university-of-petroleum-and-energy-studies-dehradun/reviews?icn=college_sub_page&amp;ici=clg_80_college_listing_tuple">106 Reviews</a></span>,
#  <span class="review_text"><a href="https://www.careers360.com/university/lovely-professional-university-phagwara/reviews?icn=college_sub_page&amp;ici=clg_155_college_listing_tuple">903 Reviews</a></span>,
# ...

# %%
soup.find_all('strong' , class_="strong_ownership")
# Out:
# [<strong class="strong_ownership">Public/Government</strong>,
#  <strong class="strong_ownership">Public/Government</strong>,
#  <strong class="strong_ownership">Public/Government</strong>,
#  <strong class="strong_ownership">Public/Government</strong>,
#  <strong class="strong_ownership">Public/Government</strong>,
#  <strong class="strong_ownership">Public/Government</strong>,
#  <strong class="strong_ownership">Public/Government</strong>,
#  <strong class="strong_ownership">Public/Government</strong>,
#  <strong class="strong_ownership">Public/Government</strong>,
#  <strong class="strong_ownership">Public/Government</strong>,
#  <strong class="strong_ownership">Public/Government</strong>,
#  <strong class="strong_ownership">Public/Government</strong>,
#  <strong class="strong_ownership">Private</strong>,
#  <strong class="strong_ownership">Private</strong>,
#  <strong class="strong_ownership">Private</strong>,
#  <strong class="strong_ownership">Private</strong>,
# ...

# %%
college = soup.find_all('div', class_= 'tupple')

# %%
len(college)
# Out:
# 50

# %%
name=[]
for i in college:
    
    name.append(i.find('h3').text.strip())

# %%
name
# Out:
# ['IIT Bombay - Indian Institute of Technology Bombay',
#  'ICT Mumbai - Institute of Chemical Technology, Mumbai',
#  'VNIT Nagpur - Visvesvaraya National Institute of Technology Nagpur',
#  'DIAT Pune - Defence Institute of Advanced Technology, Pune',
#  'COEP Pune - COEP Technological University, Pune',
#  'VJTI Mumbai - Veermata Jijabai Technological Institute, Mumbai',
#  'NMIMS Mumbai - Narsee Monjee Institute of Management Studies, Mumbai',
#  'MIT-WPU Pune - Dr Vishwanath Karad MIT World Peace University, Pune',
#  'RAIT Navi Mumbai - Ramrao Adik Institute of Technology, Navi Mumbai',
#  'VIT Pune - Vishwakarma Institute of Technology, Pune',
#  'AIT Pune - Army Institute of Technology, Pune',
#  'RCOEM Nagpur - Shri Ramdeobaba College of Engineering and Management, Nagpur',
#  'GHRCE Nagpur - GH Raisoni College of Engineering, Nagpur',
#  'Marathwada Institute of Technology, Aurangabad',
#  'NFSC Nagpur - National Fire Service College, Nagpur',
#  'Amity University, Mumbai',
# ...
